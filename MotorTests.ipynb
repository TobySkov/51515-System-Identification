# %% [markdown]
# # Motor and hub testing
#
# ### Displaying results for tests

# %%
from tests import *

# %%
visualize_data(title="Motor 1", data = load_and_format_data("tests/motor_1_program_1.txt"))
# Out:
# Reading measurements format...Done
# Reading csv data...Done

# %%
visualize_data(title="Motor 2", data = load_and_format_data("tests/motor_2_program_1.txt"))
# Out:
# Reading measurements format...Done
# Reading csv data...Done

# %%
visualize_data(title="Motor 3", data = load_and_format_data("tests/motor_3_program_1.txt"))
# Out:
# Reading measurements format...Done
# Reading csv data...Done

# %%
visualize_data(title="Motor 4", data = load_and_format_data("tests/motor_4_program_1.txt"))
# Out:
# Reading measurements format...Done
# Reading csv data...Done
